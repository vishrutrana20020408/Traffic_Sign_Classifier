# %% [markdown]
# 1. DOWNLOADS AND IMPORTS

# %%
# Fundamental classes
import numpy as np 
import pandas as pd 
import tensorflow as tf
import os

# Image related
import cv2
from PIL import Image

#Performance Plot
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
# %matplotlib inline

# For the model and it's training
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout

# %% [markdown]
# 2. LOADING THE DATADET

# %%
data = []
labels = []
classes = 43
cur_path = os.getcwd()

#Retrieving the images and their labels 
for i in range(classes):
    path = os.path.join(cur_path,'train',str(i))
    images = os.listdir(path)

    for a in images:
        try:
            image = Image.open(path + '\\'+ a)
            image = image.resize((30,30))
            image = np.array(image)
            #sim = Image.fromarray(image)
            data.append(image)
            labels.append(i)
        except:
            print("Error loading image")

#Converting lists into numpy arrays
data = np.array(data)
labels = np.array(labels)

# %% [markdown]
# 3. DATA PROCESSING

# %%
print(data.shape, labels.shape)
#Splitting training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

#Converting the labels into one hot encoding
y_train = to_categorical(y_train, 43)
y_test = to_categorical(y_test, 43)
# Out:
# (39209, 30, 30, 3) (39209,)
# (31367, 30, 30, 3) (7842, 30, 30, 3) (31367,) (7842,)

# %% [markdown]
# 4. BUILDING CNN MODEL

# %%
#Building the model
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(43, activation='softmax'))

# %%
#Compilation of the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# 5. TRAINING THE MODEL

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=25 , validation_data=(X_test, y_test))
# Out:
# Epoch 1/25
# 981/981 [==============================] - 63s 64ms/step - loss: 2.1882 - accuracy: 0.4413 - val_loss: 0.6973 - val_accuracy: 0.8271
# Epoch 2/25
# 981/981 [==============================] - 57s 59ms/step - loss: 0.9064 - accuracy: 0.7274 - val_loss: 0.4536 - val_accuracy: 0.8636
# Epoch 3/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.6827 - accuracy: 0.7963 - val_loss: 0.2631 - val_accuracy: 0.9235
# Epoch 4/25
# 981/981 [==============================] - 66s 67ms/step - loss: 0.5440 - accuracy: 0.8353 - val_loss: 0.1841 - val_accuracy: 0.9517
# Epoch 5/25
# 981/981 [==============================] - 62s 64ms/step - loss: 0.4360 - accuracy: 0.8705 - val_loss: 0.1493 - val_accuracy: 0.9569
# Epoch 6/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.3717 - accuracy: 0.8900 - val_loss: 0.1279 - val_accuracy: 0.9644
# Epoch 7/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.3477 - accuracy: 0.8958 - val_loss: 0.1762 - val_accuracy: 0.9439
# Epoch 8/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.3106 - accuracy: 0.9074 - val_loss: 0.1065 - val_accuracy: 0.9668
# Epoch 9/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.2886 - accuracy: 0.9141 - val_loss: 0.1086 - val_accuracy: 0.9662
# Epoch 10/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.3000 - accuracy: 0.9120 - val_loss: 0.0946 - val_accuracy: 0.9690
# Epoch 11/25
# 981/981 [==============================] - 60s 61ms/step - loss: 0.2804 - accuracy: 0.9169 - val_loss: 0.1023 - val_accuracy: 0.9698
# Epoch 12/25
# 981/981 [==============================] - 58s 60ms/step - loss: 0.2955 - accuracy: 0.9129 - val_loss: 0.0890 - val_accuracy: 0.9698
# Epoch 13/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.2641 - accuracy: 0.9209 - val_loss: 0.0794 - val_accuracy: 0.9763
# Epoch 14/25
# 981/981 [==============================] - 59s 60ms/step - loss: 0.2635 - accuracy: 0.9211 - val_loss: 0.0803 - val_accuracy: 0.9763
# Epoch 15/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.2878 - accuracy: 0.9159 - val_loss: 0.1218 - val_accuracy: 0.9648
# Epoch 16/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.2696 - accuracy: 0.9219 - val_loss: 0.0977 - val_accuracy: 0.9695
# Epoch 17/25
# 981/981 [==============================] - 60s 61ms/step - loss: 0.2481 - accuracy: 0.9261 - val_loss: 0.0873 - val_accuracy: 0.9727
# Epoch 18/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.2644 - accuracy: 0.9234 - val_loss: 0.0657 - val_accuracy: 0.9809
# Epoch 19/25
# 981/981 [==============================] - 60s 61ms/step - loss: 0.2634 - accuracy: 0.9225 - val_loss: 0.0941 - val_accuracy: 0.9719
# Epoch 20/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.2570 - accuracy: 0.9257 - val_loss: 0.0873 - val_accuracy: 0.9745
# Epoch 21/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.2437 - accuracy: 0.9279 - val_loss: 0.0792 - val_accuracy: 0.9768
# Epoch 22/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.2535 - accuracy: 0.9274 - val_loss: 0.0713 - val_accuracy: 0.9769
# Epoch 23/25
# 981/981 [==============================] - 59s 61ms/step - loss: 0.2419 - accuracy: 0.9297 - val_loss: 0.0788 - val_accuracy: 0.9756
# Epoch 24/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.2427 - accuracy: 0.9289 - val_loss: 0.1104 - val_accuracy: 0.9630
# Epoch 25/25
# 981/981 [==============================] - 58s 59ms/step - loss: 0.2528 - accuracy: 0.9278 - val_loss: 0.0811 - val_accuracy: 0.9756

# %% [markdown]
# 6. PLOTTING THE PERFORMANCE CURVE

# %%
#plotting graphs for accuracy 
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

#plotting graphs for loss
plt.figure(1)
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %% [markdown]
# 7. LOADING THE TEST DATASET TO TEST THE MODEL

# %%
y_test = pd.read_csv('Test.csv')

labels = y_test["ClassId"].values
imgs = y_test["Path"].values

data=[]

for img in imgs:
    image = Image.open(img)
    image = image.resize((30,30))
    data.append(np.array(image))

X_test=np.array(data)

# %%
with tf.device('/GPU:0'):
    pred = np.argmax(model.predict(X_test), axis=-1)

print(accuracy_score(labels, pred))
# Out:
# 395/395 [==============================] - 6s 15ms/step
# 0.9371338083927158

# %% [markdown]
# 8. SAVE THE MODEL

# %%
# Saving the Model 
model.save('traffic_classifier.h5')

# %% [markdown]
# 9. LOAD THE MODEL

# %%
model2 = load_model('traffic_classifier.h5')

# %%
# Classes of trafic signs
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %%
def test_on_img(img):
    data=[]
    image = Image.open(img)
    image = image.resize((30,30))
    data.append(np.array(image))
    X_test=np.array(data)
    Y_pred = np.argmax(model.predict(X_test), axis=-1)
    return image,Y_pred

# %%
plot,prediction = test_on_img(r'C:\Users\prami\OneDrive\Desktop\Traffic_Sign_Classifier\Test\00001.png')
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step
# Predicted traffic sign is:  Speed limit (30km/h)

# %%
plot,prediction = test_on_img(r'C:\Users\prami\OneDrive\Desktop\Traffic_Sign_Classifier\Test\00002.png')
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Predicted traffic sign is:  Keep right

# %%
plot,prediction = test_on_img(r'C:\Users\prami\OneDrive\Desktop\Traffic_Sign_Classifier\Test\00003.png')
s = [str(i) for i in prediction] 
a = int("".join(s)) 
print("Predicted traffic sign is: ", classes[a])
plt.imshow(plot)
plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Predicted traffic sign is:  Turn right ahead
